# %%
import mdtraj as md

PDBID = "7lak"
replica = 5
PC_num = 1
NMs = 1000
NMs2 = 10

pdb1 = f"results/{PDBID}/replica_{replica}/pc1_nma_projection/rep{replica}_pc{PC_num}_lowest{NMs}nm_minus.pdb"
#pdb2 = f"results/{PDBID}/replica_0/pc1_nma_projection/stopped.pdb"
pdb2 = f"results/{PDBID}/replica_{replica}/pc1_nma_projection/rep{replica}_pc{PC_num}_lowest{NMs2}nm_minus.pdb"

ref = md.load(pdb2)
mob = md.load(pdb1)

# Use C-alpha atoms for alignment and RMSD
ref_sel = ref.topology.select("protein and name CA")
mob_sel = mob.topology.select("protein and name CA")

if len(ref_sel) != len(mob_sel):
    raise ValueError(
        f"Different number of selected atoms: "
        f"ref={len(ref_sel)}, mobile={len(mob_sel)}"
    )

# Align mobile onto reference using the same atoms
mob.superpose(
    ref,
    atom_indices=mob_sel,
    ref_atom_indices=ref_sel,
)

# Calculate RMSD after alignment
rmsd_nm = md.rmsd(
    mob,
    ref,
    atom_indices=mob_sel,
)

mob.save_pdb(f"results/{PDBID}/replica_{replica}/pc1_nma_projection/{PDBID}_rep{replica}_aligned{NMs}_{NMs2}.pdb")
print(f"Aligned structure saved to results/{PDBID}/replica_{replica}/pc1_nma_projection/aligned{NMs}_{NMs2}.pdb")

print(f"Aligned C-alpha RMSD: {rmsd_nm[0]:.4f} nm")
print(f"Aligned C-alpha RMSD: {rmsd_nm[0] * 10:.4f} Å")
# Out:
# Aligned structure saved to results/7lak/replica_5/pc1_nma_projection/aligned1000_10.pdb
# Aligned C-alpha RMSD: 0.0636 nm
# Aligned C-alpha RMSD: 0.6364 Å

# %%
import mdtraj as md

replica = 5
PC_num = 1
NMs = 1000
NMs2 = 10

pdb1 = f"results/{PDBID}/replica_{replica}/pc1_nma_projection/{PDBID}_rep{replica}_aligned{NMs}_{NMs2}.pdb"
pdb2 = f"results/{PDBID}/replica_0/pc1_nma_projection/stopped.pdb"

ref = md.load(pdb2)
mob = md.load(pdb1)

# Use C-alpha atoms for alignment and RMSD
ref_sel = ref.topology.select("protein and name CA")
mob_sel = mob.topology.select("protein and name CA")

if len(ref_sel) != len(mob_sel):
    raise ValueError(
        f"Different number of selected atoms: "
        f"ref={len(ref_sel)}, mobile={len(mob_sel)}"
    )

# Align mobile onto reference using the same atoms
mob.superpose(
    ref,
    atom_indices=mob_sel,
    ref_atom_indices=ref_sel,
)

# Calculate RMSD after alignment
rmsd_nm = md.rmsd(
    mob,
    ref,
    atom_indices=mob_sel,
)

mob.save_pdb(f"results/{PDBID}/replica_{replica}/pc1_nma_projection/{PDBID}_rep{replica}_aligned{NMs}_{NMs2}_stop.pdb")
print(f"Aligned structure saved to results/{PDBID}/replica_{replica}/pc1_nma_projection/aligned{NMs}_{NMs2}_stop.pdb")

print(f"Aligned C-alpha RMSD: {rmsd_nm[0]:.4f} nm")
print(f"Aligned C-alpha RMSD: {rmsd_nm[0] * 10:.4f} Å")
# Out:
# Aligned structure saved to results/7lak/replica_5/pc1_nma_projection/aligned1000_10_stop.pdb
# Aligned C-alpha RMSD: 0.0755 nm
# Aligned C-alpha RMSD: 0.7548 Å

# %%
import mdtraj as md

replica = 5
PC_num = 1
NMs = 10
NMs2 = 10

pdb1 = f"results/{PDBID}/replica_{replica}/pc1_nma_projection/rep{replica}_pc{PC_num}_lowest{NMs}nm_minus.pdb"
pdb2 = f"results/{PDBID}/replica_0/pc1_nma_projection/stopped.pdb"

ref = md.load(pdb2)
mob = md.load(pdb1)

# Use C-alpha atoms for alignment and RMSD
ref_sel = ref.topology.select("protein and name CA")
mob_sel = mob.topology.select("protein and name CA")

if len(ref_sel) != len(mob_sel):
    raise ValueError(
        f"Different number of selected atoms: "
        f"ref={len(ref_sel)}, mobile={len(mob_sel)}"
    )

# Align mobile onto reference using the same atoms
mob.superpose(
    ref,
    atom_indices=mob_sel,
    ref_atom_indices=ref_sel,
)

# Calculate RMSD after alignment
rmsd_nm = md.rmsd(
    mob,
    ref,
    atom_indices=mob_sel,
)

mob.save_pdb(f"results/{PDBID}/replica_{replica}/pc1_nma_projection/{PDBID}_rep{replica}_aligned{NMs}_ref.pdb")
print(f"Aligned structure saved to results/{PDBID}/replica_{replica}/pc1_nma_projection/aligned{NMs}_ref.pdb")

print(f"Aligned C-alpha RMSD: {rmsd_nm[0]:.4f} nm")
print(f"Aligned C-alpha RMSD: {rmsd_nm[0] * 10:.4f} Å")
# Out:
# Aligned structure saved to results/7lak/replica_5/pc1_nma_projection/aligned10_ref.pdb
# Aligned C-alpha RMSD: 0.0813 nm
# Aligned C-alpha RMSD: 0.8133 Å

# %%
import mdtraj as md

PDBID = "7lak"
replica = 5
PC_num = 1
NMs = 1000
NMs2 = 10

pdb1 = f"results/{PDBID}/replica_{replica}/pc1_nma_projection/rep{replica}_pc{PC_num}_lowest{NMs}nm_minus.pdb"
#pdb2 = f"results/{PDBID}/replica_0/pc1_nma_projection/stopped.pdb"
pdb2 = f"results/{PDBID}/replica_{replica}/pc1_nma_projection_new/rep{replica}_pc{PC_num}_lowest{NMs}nm_minus.pdb"

ref = md.load(pdb2)
mob = md.load(pdb1)

# Use C-alpha atoms for alignment and RMSD
ref_sel = ref.topology.select("protein and name CA")
mob_sel = mob.topology.select("protein and name CA")

if len(ref_sel) != len(mob_sel):
    raise ValueError(
        f"Different number of selected atoms: "
        f"ref={len(ref_sel)}, mobile={len(mob_sel)}"
    )

# Align mobile onto reference using the same atoms
mob.superpose(
    ref,
    atom_indices=mob_sel,
    ref_atom_indices=ref_sel,
)

# Calculate RMSD after alignment
rmsd_nm = md.rmsd(
    mob,
    ref,
    atom_indices=mob_sel,
)

mob.save_pdb(f"results/{PDBID}/replica_{replica}/pc1_nma_projection_new/{PDBID}_rep{replica}_aligned_with_old.pdb")
print(f"Aligned structure saved to results/{PDBID}/replica_{replica}/pc1_nma_projection_new/aligned{NMs}_{NMs2}.pdb")

print(f"Aligned C-alpha RMSD: {rmsd_nm[0]:.4f} nm")
print(f"Aligned C-alpha RMSD: {rmsd_nm[0] * 10:.4f} Å")
# Out:
# Aligned structure saved to results/7lak/replica_5/pc1_nma_projection_new/aligned1000_10.pdb
# Aligned C-alpha RMSD: 0.0000 nm
# Aligned C-alpha RMSD: 0.0000 Å

# %%
from pathlib import Path
import numpy as np

outdir = Path("results/7lak/replica_5/pc1_nma_projection_new")

for f in sorted(outdir.glob("*.npy")):
    arr = np.load(f)
    print(f.name, arr.shape, arr.dtype)

    coef = np.load(outdir / "coef.npy")
captured = np.load(outdir / "captured.npy")
amplitude = None  # amplitude is written in summary.txt, not as .npy unless you added it
dr_dir = np.load(outdir / "dr_dir.npy")
dr_scaled_atoms = np.load(outdir / "dr_scaled_atoms.npy")
xyz_minus = np.load(outdir / "xyz_minus.npy")
xyz_plus = np.load(outdir / "xyz_plus.npy")

print("coef:", coef)
print("captured:", captured)
print("dr_dir shape:", dr_dir.shape)
print("dr_scaled_atoms shape:", dr_scaled_atoms.shape)
print("xyz_minus shape:", xyz_minus.shape)
print("xyz_plus shape:", xyz_plus.shape)
# Out:
# bio3d_mode_numbers.npy (100,) int64
# captured.npy (1,) float64
# coef.npy (100,) float64
# coef_magnitudes_from_eigenvalues.npy (100,) float64
# dr_dir.npy (2997,) float64
# dr_scaled_atoms.npy (999, 3) float64
# mode_indices_zero_based.npy (100,) int64
# nma_eigenvalues_all.npy (2997,) float64
# pc_eigenvalue.npy (1,) float64
# pc_nm_overlap.npy (1,) float64
# pc_vector.npy (2997,) float64
# projection_signs.npy (100,) float64
# selected_nma_eigenvalues.npy (100,) float64
# xyz_minus.npy (999, 3) float64
# xyz_plus.npy (999, 3) float64
# coef: [ 0.65783608  0.39574812 -0.24905353 -0.18194882  0.16183857  0.14100609
#  -0.1381456  -0.12163293  0.11565669 -0.1017465   0.09652924  0.09001021
#   0.08813808  0.08316327  0.07948548 -0.07659257 -0.07201173 -0.07183976
#  -0.06953732 -0.06850973 -0.06774504 -0.06660872 -0.06499458  0.06308067
#  -0.06146872 -0.06107241 -0.05969942  0.05887387 -0.05759762  0.05663462
#  -0.05518401  0.05425991  0.05362677  0.05318627 -0.0526219   0.05219817
#  -0.05163592  0.04974485 -0.04862684  0.04825428 -0.04776767  0.04671969
#   0.04584161 -0.04569427 -0.04541684 -0.04485635  0.04433995  0.04395962
#  -0.04341089  0.04295866  0.04241409  0.04213108 -0.04170152  0.04091446
#  -0.04070374 -0.04066476  0.04006937 -0.03990469 -0.03965081  0.03892219
#  -0.03850745 -0.03816404  0.03798399  0.03739996  0.03723244 -0.03686509
#  -0.03668854  0.03628835 -0.03606297  0.03588852 -0.03581831  0.0357266
#  -0.03532665  0.03519221 -0.0348899   0.03453973  0.03421597 -0.03399516
#   0.03376026 -0.03349713  0.0331117  -0.03299778  0.03269245 -0.0326106
#  -0.03237015 -0.03227318  0.03192973 -0.03164198 -0.03148732 -0.03101497
#   0.0309581   0.03090538 -0.03072382 -0.03055891  0.03034854 -0.03022142
#   0.03015365 -0.02996941 -0.02981612 -0.02960955]
# captured: [0.39791109]
# dr_dir shape: (2997,)
# dr_scaled_atoms shape: (999, 3)
# xyz_minus shape: (999, 3)
# xyz_plus shape: (999, 3)

# %%
import pandas as pd

pdb = "7lak"
base_dir = Path("results")

nma_dir = base_dir / pdb / "nma"

eigvals_all = np.load(nma_dir / "eigenvalues_all.npy")

print("shape:", eigvals_all.shape)
print("dtype:", eigvals_all.dtype)
print(eigvals_all[:20])
# Out:
# shape: (2997,)
# dtype: float64
# [ 0.        0.        0.       -0.       -0.       -0.        0.000515
#   0.001423  0.003593  0.006732  0.008509  0.011209  0.011678  0.015064
#   0.016661  0.021528  0.023918  0.027508  0.028689  0.032224]

# %%
import numpy as np
from pathlib import Path

#check final directions

dirs = {
    "projection": Path("results/7lak/replica_5/pc1_nma_projection/dr_dir.npy"),
    "inverse_sqrt": Path("results/7lak/replica_5/pc1_nma_projection_new/dr_dir.npy"),
    "inverse": Path("results/7lak/replica_5/pc1_nma_projection_inverse/dr_dir.npy"),
}

loaded = {}

for name, path in dirs.items():
    if path.exists():
        v = np.load(path).reshape(-1)
        v = v / np.linalg.norm(v)
        loaded[name] = v
        print(name, "loaded", v.shape)
    else:
        print(name, "missing:", path)

        names = list(loaded)

for i in range(len(names)):
    for j in range(i + 1, len(names)):
        a = loaded[names[i]]
        b = loaded[names[j]]

        cos = np.dot(a, b)
        abs_cos = abs(cos)

        print(f"{names[i]} vs {names[j]}")
        print("  cosine:", cos)
        print("  abs cosine:", abs_cos)
# Out:
# projection loaded (2997,)
# inverse_sqrt loaded (2997,)
# inverse missing: results/7lak/replica_5/pc1_nma_projection_inverse/dr_dir.npy
# projection vs inverse_sqrt
#   cosine: 0.039948416185004915
#   abs cosine: 0.039948416185004915
